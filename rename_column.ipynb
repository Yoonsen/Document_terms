# %%
import dhlab as dh

# %%
['4'] + ['1','3']
# Out:
# ['4', '1', '3']

# %%
c = dh.Corpus(doctype="digibok")

# %%
counts = dh.Counts(c, words = "han hun".split())

# %%
counts.counts
# Out:
# urn   URN:NBN:no-nb_digibok_2008070704011  \
# word
# han                                 121.0
# hun                                   3.0
#
# urn   URN:NBN:no-nb_digibok_2009052604008  \
# word
# han                                  40.0
# hun                                   0.0
#
# urn   URN:NBN:no-nb_digibok_2011070605001  \
# word
# han                                 597.0
# hun                                   0.0
#
# urn   URN:NBN:no-nb_digibok_2012062506017  \
# word
# han                                   3.0
# hun                                   3.0
#
# urn   URN:NBN:no-nb_digibok_2014031006126  \
# word
# han                                  19.0
# hun                                  21.0
#
# urn   URN:NBN:no-nb_digibok_2017080107077  \
# word
# han                                 937.0
# hun                                 400.0
#
# urn   URN:NBN:no-nb_digibok_2018031448055  URN:NBN:no-nb_digibok_2021072948067
# word
# ...

# %%
c.corpus[['urn', 'title','year']].values
# Out:
# array([['URN:NBN:no-nb_digibok_2012062506017',
#         'OMI og aktuelle skoleforskningsprosjekter : rapport fra konferanse på Sundvolden august 1980',
#         1980],
#        ['URN:NBN:no-nb_digibok_2011070605001', 'Nær nok : noveller',
#         2004],
#        ['URN:NBN:no-nb_digibok_2017080107077', 'David Grieve : roman. 1',
#         1892],
#        ['URN:NBN:no-nb_digibok_2008070704011',
#         'Fedreland og fritid : en mellomkrigsstudie i Noregs ungdomslag',
#         1995],
#        ['URN:NBN:no-nb_digibok_2009052604008',
#         'Bedriftslære for yrkesfaga : Arbeidsbok til', 1990],
#        ['URN:NBN:no-nb_digibok_2012071908003',
#         'Folketellingen 1. november 1960 : tellingsresultater : tilbakegående tall : prognoser : <Kommunevis> : 2027 Nesseby',
#         1962],
#        ['URN:NBN:no-nb_digibok_2018031448055',
#         'Internasjonale lover for turneringsbridge 1987', 1987],
#        ['URN:NBN:no-nb_digibok_2014031006126', 'Skorpen', 2011],
# ...

# %%
names = {x[0]:' '.join([str(z) for z in x[1:]]) for x in c.corpus[['urn', 'title','year']].values}

# %%
counts.counts.rename(columns=names)
# Out:
# urn   Fedreland og fritid : en mellomkrigsstudie i Noregs ungdomslag 1995  \
# word
# han                                               121.0
# hun                                                 3.0
#
# urn   Bedriftslære for yrkesfaga : Arbeidsbok til 1990  \
# word
# han                                               40.0
# hun                                                0.0
#
# urn   Nær nok : noveller 2004  \
# word
# han                     597.0
# hun                       0.0
#
# urn   OMI og aktuelle skoleforskningsprosjekter : rapport fra konferanse på Sundvolden august 1980 1980  \
# word
# han                                                 3.0
# hun                                                 3.0
#
# urn   Skorpen 2011  David Grieve : roman. 1 1892  \
# word
# han           19.0                         937.0
# hun           21.0                         400.0
#
# urn   Internasjonale lover for turneringsbridge 1987 1987  \
# word
# ...

# %%
counts.counts
# Out:
# urn   URN:NBN:no-nb_digibok_2008070704011  \
# word
# han                                 121.0
# hun                                   3.0
#
# urn   URN:NBN:no-nb_digibok_2009052604008  \
# word
# han                                  40.0
# hun                                   0.0
#
# urn   URN:NBN:no-nb_digibok_2011070605001  \
# word
# han                                 597.0
# hun                                   0.0
#
# urn   URN:NBN:no-nb_digibok_2012062506017  \
# word
# han                                   3.0
# hun                                   3.0
#
# urn   URN:NBN:no-nb_digibok_2014031006126  \
# word
# han                                  19.0
# hun                                  21.0
#
# urn   URN:NBN:no-nb_digibok_2017080107077  \
# word
# han                                 937.0
# hun                                 400.0
#
# urn   URN:NBN:no-nb_digibok_2018031448055  URN:NBN:no-nb_digibok_2021072948067
# word
# ...
